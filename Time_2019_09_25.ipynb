# %%
# %matplotlib notebook
from ipywidgets import *
import numpy as np
import matplotlib.pyplot as plt
import time

fs=8000 # Hz
ts = 1/fs
N = 8
n = np.arange(0,N,1)

x = np.sin(2*np.pi*1000*n*ts) + 0.5*np.sin(2*np.pi*2000*n*ts + 3*np.pi/8)
print(x)
# Out:
# [ 0.46193977  0.8984485   0.53806023  0.51576507  0.46193977 -0.51576507
#  -1.46193977 -0.8984485 ]

# %%
X=0
m=1
for n in range(N):
    X = X + x[n]*(np.cos(2*np.pi*m*n/8)-1j*np.sin(2*np.pi*m*n/8))

print(X)
# Out:
# (-3.3306690738754696e-16-4j)

# %%
fs=8000 # Hz
ts = 1/fs
N = 8
n = np.arange(0,N,1)

x = np.sin(2*np.pi*1000*n*ts) + 0.5*np.sin(2*np.pi*2000*n*ts + 3*np.pi/8)

X=np.zeros(N,dtype=np.complex)

for m in range(N):
    for n in range(N):
        X[m] = X[m] + x[n]*(np.cos(2*np.pi*m*n/N)-1j*np.sin(2*np.pi*m*n/N))
m=np.arange(0,N)
f = m*fs/N
plt.figure()
plt.plot(f,np.abs(X),'o')
plt.xlabel('Frekvens (Hz)')
plt.ylabel('Magnitude')
plt.ylim(0,np.max(np.abs(X)))
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">
